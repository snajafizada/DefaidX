# %%
import pandas as pd
from pathlib import Path

# %%
raw_path  = Path(r"C:\\Users\\snaja\\OneDrive\\defaidX\\data\\raw\\sipri\\defense_spending_share_gov.csv")

df = pd.read_csv(raw_path)

# %%
df.head()
# Out:
#         Country      1992      1993      1994      1995      1996      1997  \
# 0        Africa       NaN       NaN       NaN       NaN       NaN       NaN
# 1  North Africa       NaN       NaN       NaN       NaN       NaN       NaN
# 2       Algeria  0.069904  0.070861  0.093684  0.093543  0.106039  0.117514
# 3         Libya       NaN       NaN       NaN       NaN       NaN  0.116873
# 4       Morocco  0.151130  0.158109  0.162983  0.160040  0.176140  0.177801
#
#        1998      1999      2000  ...      2014      2015      2016      2017  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 2  0.127172  0.117222  0.120050  ...  0.134377  0.135656  0.152039  0.146409
# 3  0.142135  0.115252  0.102678  ...  0.109068       NaN       NaN       NaN
# 4  0.170343  0.121357  0.109042  ...  0.110783  0.104176  0.104448  0.105925
#
#        2018      2019      2020      2021      2022      2023
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.135999  0.143587  0.156940  0.150250  0.126723  0.193357
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4  0.104896  0.104736  0.116552  0.120053  0.118359  0.111220
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Country', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
# Get unique country names
unique_countries = df['Country'].unique()
print(unique_countries)
# Out:
# ['Africa' 'North Africa' 'Algeria' 'Libya' 'Morocco' 'Tunisia'
#  'sub-Saharan Africa' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Burundi'
#  'Cameroon' 'Cape Verde' 'Central African Republic' 'Chad' 'Congo, DR'
#  'Congo, Republic' "Cote d'Ivoire" 'Djibouti' 'Equatorial Guinea'
#  'Eritrea' 'Ethiopia' 'Gabon' 'Gambia, The' 'Ghana' 'Guinea'
#  'Guinea-Bissau' 'Kenya' 'Lesotho' 'Liberia' 'Madagascar' 'Malawi' 'Mali'
#  'Mauritania' 'Mauritius' 'Mozambique' 'Namibia' 'Niger' 'Nigeria'
#  'Rwanda' 'Senegal' 'Seychelles' 'Sierra Leone' 'Somalia' 'South Africa'
#  'South Sudan' 'Sudan' 'Eswatini' 'Tanzania' 'Togo' 'Uganda' 'Zambia'
#  'Zimbabwe' 'Americas' 'Central America and the Caribbean' 'Belize'
#  'Costa Rica' 'Cuba' 'Dominican Republic' 'El Salvador' 'Guatemala'
#  'Haiti' 'Honduras' 'Jamaica' 'Mexico' 'Nicaragua' 'Panama'
#  'Trinidad and Tobago' 'North America' 'Canada' 'United States of America'
#  'South America' 'Argentina' 'Bolivia' 'Brazil' 'Chile' 'Colombia'
#  'Ecuador' 'Guyana' 'Paraguay' 'Peru' 'Uruguay' 'Venezuela'
#  'Asia & Oceania' 'Oceania' 'Australia' 'Fiji' 'New Zealand'
#  'Papua New Guinea' 'South Asia' 'Afghanistan' 'Bangladesh' 'India'
#  'Nepal' 'Pakistan' 'Sri Lanka' 'East Asia' 'China' 'Japan' 'Korea, North'
#  'Korea, South' 'Mongolia' 'Taiwan' 'South East Asia' 'Brunei' 'Cambodia'
#  'Indonesia' 'Laos' 'Malaysia' 'Myanmar' 'Philippines' 'Singapore'
#  'Thailand' 'Timor Leste' 'Viet Nam' 'Central Asia' 'Kazakhstan'
#  'Kyrgyz Republic' 'Tajikistan' 'Turkmenistan' 'Uzbekistan' 'Europe'
#  'Central Europe' 'Albania' 'Bosnia and Herzegovina' 'Bulgaria' 'Croatia'
#  'Czechia' 'Czechoslovakia' 'Estonia' 'German Democratic Republic'
#  'Hungary' 'Kosovo' 'Latvia' 'Lithuania' 'North Macedonia' 'Montenegro'
#  'Poland' 'Romania' 'Serbia' 'Slovakia' 'Slovenia' 'Yugoslavia'
#  'Eastern Europe' 'Armenia' 'Azerbaijan' 'Belarus' 'Georgia' 'Moldova'
#  'Russia' 'Ukraine' 'USSR' 'Western Europe' 'Austria' 'Belgium' 'Cyprus'
#  'Denmark' 'Finland' 'France' 'Germany' 'Greece' 'Iceland' 'Ireland'
#  'Italy' 'Luxembourg' 'Malta' 'Netherlands' 'Norway' 'Portugal' 'Spain'
#  'Sweden' 'Switzerland' 'United Kingdom' 'European Union' 'Middle East'
#  'Bahrain' 'Egypt' 'Iran' 'Iraq' 'Israel' 'Jordan' 'Kuwait' 'Lebanon'
#  'Oman' 'Qatar' 'Saudi Arabia' 'Syria' 'TÃ¼rkiye' 'United Arab Emirates'
#  'Yemen, North' 'Yemen']

# %%
# List of known aggregate/non-country entries to exclude
non_countries = [
    # ----- Global / income groups
    "World", "High income", "Low income", "Lower middle income",
    "Upper middle income", "Low & middle income", "Middle income",

    # ----- Broad geographic aggregates
    "Africa", "North Africa", "sub-Saharan Africa",
    "Americas", "North America", "South America",
    "Asia & Oceania", "Oceania",
    "Europe", "Central Europe",
    "Middle East",
    "South Asia", "East Asia", "South East Asia", "Central Asia",
    "USSR",                     # historical
    "Western Europe",           # regional aggregate
    "Eastern Europe",           # if also found, for completeness
    "Southern Europe",          # sometimes used in groupings
    "Northern Europe",          # idem

    # ----- Regional sub-aggregates
    "Central America and the Caribbean",
    "European Union",

    # ----- World Bank / development classifications
    "Fragile and conflict affected situations", "Fragile situations",
    "Heavily indebted poor countries (HIPC)",
    "IDA only", "IDA blend", "IDA total",
    "IDA & IBRD total", "IBRD only",
    "Least developed countries: UN classification",
    "World Bank high income", "World Bank low income",
    "World Bank middle income", "World Bank upper middle income",
    "World Bank lower middle income",

    # ----- OECD / other groupings
    "OECD members", "OECD", "Euro area",

    # ----- Demographic groupings
    "Early-demographic dividend", "Late-demographic dividend",
    "Post-demographic dividend", "Pre-demographic dividend",

    # ----- Small-state & territory aggregates
    "Caribbean small states", "Pacific island small states",
    "Other small states", "Small states",

    # ----- Sub-regional aggregates already present
    "Latin America & Caribbean",
    "Latin America & Caribbean (excluding high income)",
    "Latin America & the Caribbean (IDA & IBRD countries)",
    "East Asia & Pacific", "East Asia & Pacific (excluding high income)",
    "East Asia & Pacific (IDA & IBRD countries)",
    "Europe & Central Asia", "Europe & Central Asia (excluding high income)",
    "Europe & Central Asia (IDA & IBRD countries)",
    "Middle East & North Africa",
    "Middle East & North Africa (excluding high income)",
    "Middle East & North Africa (IDA & IBRD countries)",
    "Sub-Saharan Africa (excluding high income)",
    "Sub-Saharan Africa (IDA & IBRD countries)",
    "South Asia (IDA & IBRD)",
    "Africa Eastern and Southern", "Africa Western and Central",
    "Central Europe and the Baltics",

    # ----- Historical / defunct states & entities
    "Czechoslovakia", "German Democratic Republic", "Yemen, North",

    # ----- Territories & special areas
    "American Samoa", "Anguilla", "Aruba", "Bermuda",
    "British Virgin Islands", "Cayman Islands", "Channel Islands",
    "Curacao", "Faroe Islands", "French Polynesia", "Gibraltar",
    "Greenland", "Guam", "Isle of Man", "Jersey", "Guernsey",
    "Macao SAR, China", "Hong Kong SAR, China", "Marshall Islands",
    "Northern Mariana Islands", "Palau", "Puerto Rico",
    "Sint Maarten (Dutch part)", "New Caledonia",
    "Virgin Islands (U.S.)", "West Bank and Gaza",
    "Kosovo",  # UN-disputed; treat as non-sovereign if desired

    # ----- Additional non-sovereign or grouped codes encountered
    "Not classified",
]

# 1. Filter out non-countries
df_filtered = df[~df['Country'].isin(non_countries)].copy()


# Reset index so it goes from 0 to len(df)-1
df_filtered = df_filtered.reset_index(drop=True)

# 2. Normalize country names: strip whitespace and consistent capitalization
df_filtered['Country'] = df_filtered['Country'].str.strip()
df_filtered['Country'] = df_filtered['Country'].str.replace(' And ', ' and ', regex=False)
df_filtered['Country'] = df_filtered['Country'].str.replace(' Of ', ' of ', regex=False)
df_filtered['Country'] = df_filtered['Country'].str.replace(' Dr', ' DR', regex=False)

# 3. Manual fixes for spelling/formatting inconsistencies
df_filtered['Country'] = df_filtered['Country'].replace({
    'TÃ¼rkiye': 'Türkiye',
    'Tã¼rkiye': 'Türkiye',
    'Turkiye': 'Türkiye',
    "Cote D'Ivoire": "Cote d'Ivoire",
    'Bosnia And Herzegovina': 'Bosnia and Herzegovina',
    'Trinidad And Tobago': 'Trinidad and Tobago',
    'United States of America': 'United States',
    'Cape Verde': 'Cabo Verde',
    'Congo, DR': 'Congo, Dem. Rep.',
    'Congo, Republic': 'Congo, Rep.',
    'Korea, South': 'South Korea',
    'Korea, Rep.': 'South Korea',
    'Brunei Darussalam': 'Brunei',
    'Lao PDR': 'Laos',
    'Timor Leste': 'Timor-Leste',
    'Russian Federation': 'Russia',
    'Iran, Islamic Rep.': 'Iran',
    'Egypt, Arab Rep.': 'Egypt',
    'Slovak Republic': 'Slovakia',
    'Yemen, Rep.': 'Yemen',
    'Bahamas, The' : 'The Bahamas',
    'Venezuela, RB': 'Venezuela',
    'Viet Nam' : 'Vietnam',
    'Russian Federation': 'Russia',
    'Iran, Islamic Rep.': 'Iran',
    'Korea, Rep.': 'South Korea',
    "Korea, Dem. People's Rep.": 'North Korea',
    'Egypt, Arab Rep.': 'Egypt',
    'Lao PDR': 'Laos',
    'Venezuela, RB': 'Venezuela',
    'Slovak Republic': 'Slovakia',
    'Syrian Arab Republic': 'Syria',
    'Gambia, The': 'The Gambia',
    'Bahamas, The': 'The Bahamas',
    'Brunei Darussalam': 'Brunei',
    'Cabo Verde': 'Cape Verde',
    'Timor-Leste': 'Timor Leste',
    'Congo, Dem. Rep.': 'Congo (Kinshasa)',
    'Congo, Rep.': 'Congo (Brazzaville)',
    'Cote d\'Ivoire': 'Ivory Coast',

})

# 4. Convert year columns from object (string) to numeric (float), handling errors gracefully
years = [str(y) for y in range(1992, 2025)]
for year in years:
    if year in df_filtered.columns:
        df_filtered[year] = pd.to_numeric(df_filtered[year], errors='coerce')


# Now df is filtered and country names are standardized, ready for analysis
print(f"Data shape after filtering and cleaning: {df_filtered.shape}")
print("Unique countries after cleaning:", df_filtered['Country'].unique())
# Out:
# Data shape after filtering and cleaning: (168, 33)
# Unique countries after cleaning: ['Algeria' 'Libya' 'Morocco' 'Tunisia' 'Angola' 'Benin' 'Botswana'
#  'Burkina Faso' 'Burundi' 'Cameroon' 'Cabo Verde'
#  'Central African Republic' 'Chad' 'Congo, Dem. Rep.' 'Congo, Rep.'
#  'Ivory Coast' 'Djibouti' 'Equatorial Guinea' 'Eritrea' 'Ethiopia' 'Gabon'
#  'The Gambia' 'Ghana' 'Guinea' 'Guinea-Bissau' 'Kenya' 'Lesotho' 'Liberia'
#  'Madagascar' 'Malawi' 'Mali' 'Mauritania' 'Mauritius' 'Mozambique'
#  'Namibia' 'Niger' 'Nigeria' 'Rwanda' 'Senegal' 'Seychelles'
#  'Sierra Leone' 'Somalia' 'South Africa' 'South Sudan' 'Sudan' 'Eswatini'
#  'Tanzania' 'Togo' 'Uganda' 'Zambia' 'Zimbabwe' 'Belize' 'Costa Rica'
#  'Cuba' 'Dominican Republic' 'El Salvador' 'Guatemala' 'Haiti' 'Honduras'
#  'Jamaica' 'Mexico' 'Nicaragua' 'Panama' 'Trinidad and Tobago' 'Canada'
#  'United States' 'Argentina' 'Bolivia' 'Brazil' 'Chile' 'Colombia'
#  'Ecuador' 'Guyana' 'Paraguay' 'Peru' 'Uruguay' 'Venezuela' 'Australia'
#  'Fiji' 'New Zealand' 'Papua New Guinea' 'Afghanistan' 'Bangladesh'
#  'India' 'Nepal' 'Pakistan' 'Sri Lanka' 'China' 'Japan' 'Korea, North'
#  'South Korea' 'Mongolia' 'Taiwan' 'Brunei' 'Cambodia' 'Indonesia' 'Laos'
#  'Malaysia' 'Myanmar' 'Philippines' 'Singapore' 'Thailand' 'Timor-Leste'
#  'Vietnam' 'Kazakhstan' 'Kyrgyz Republic' 'Tajikistan' 'Turkmenistan'
#  'Uzbekistan' 'Albania' 'Bosnia and Herzegovina' 'Bulgaria' 'Croatia'
#  'Czechia' 'Estonia' 'Hungary' 'Latvia' 'Lithuania' 'North Macedonia'
#  'Montenegro' 'Poland' 'Romania' 'Serbia' 'Slovakia' 'Slovenia'
#  'Yugoslavia' 'Armenia' 'Azerbaijan' 'Belarus' 'Georgia' 'Moldova'
#  'Russia' 'Ukraine' 'Austria' 'Belgium' 'Cyprus' 'Denmark' 'Finland'
#  'France' 'Germany' 'Greece' 'Iceland' 'Ireland' 'Italy' 'Luxembourg'
#  'Malta' 'Netherlands' 'Norway' 'Portugal' 'Spain' 'Sweden' 'Switzerland'
#  'United Kingdom' 'Bahrain' 'Egypt' 'Iran' 'Iraq' 'Israel' 'Jordan'
#  'Kuwait' 'Lebanon' 'Oman' 'Qatar' 'Saudi Arabia' 'Syria' 'Türkiye'
#  'United Arab Emirates' 'Yemen']

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  168 non-null    object
#  1   1992     75 non-null     float64
#  2   1993     82 non-null     float64
#  3   1994     87 non-null     float64
#  4   1995     102 non-null    float64
#  5   1996     105 non-null    float64
#  6   1997     113 non-null    float64
#  7   1998     115 non-null    float64
#  8   1999     118 non-null    float64
#  9   2000     133 non-null    float64
#  10  2001     137 non-null    float64
#  11  2002     142 non-null    float64
#  12  2003     146 non-null    float64
#  13  2004     148 non-null    float64
#  14  2005     151 non-null    float64
#  15  2006     146 non-null    float64
#  16  2007     144 non-null    float64
#  17  2008     149 non-null    float64
#  18  2009     145 non-null    float64
#  19  2010     144 non-null    float64
#  20  2011     142 non-null    float64
#  21  2012     148 non-null    float64
#  22  2013     151 non-null    float64
#  23  2014     152 non-null    float64
#  24  2015     148 non-null    float64
#  25  2016     149 non-null    float64
#  26  2017     149 non-null    float64
#  27  2018     151 non-null    float64
#  28  2019     149 non-null    float64
#  29  2020     149 non-null    float64
#  30  2021     150 non-null    float64
#  31  2022     148 non-null    float64
#  32  2023     146 non-null    float64
# dtypes: float64(32), object(1)
# memory usage: 43.4+ KB

# %%
df_filtered.head()
# Out:
#    Country      1992      1993      1994      1995      1996      1997  \
# 0  Algeria  0.069904  0.070861  0.093684  0.093543  0.106039  0.117514
# 1    Libya       NaN       NaN       NaN       NaN       NaN  0.116873
# 2  Morocco  0.151130  0.158109  0.162983  0.160040  0.176140  0.177801
# 3  Tunisia  0.063291  0.061916  0.064018  0.062582  0.066741  0.067090
# 4   Angola       NaN       NaN       NaN       NaN  0.060329  0.138755
#
#        1998      1999      2000  ...      2014      2015      2016      2017  \
# 0  0.127172  0.117222  0.120050  ...  0.134377  0.135656  0.152039  0.146409
# 1  0.142135  0.115252  0.102678  ...  0.109068       NaN       NaN       NaN
# 2  0.170343  0.121357  0.109042  ...  0.110783  0.104176  0.104448  0.105925
# 3  0.066169  0.061789  0.061377  ...  0.065263  0.077960  0.081760  0.070733
# 4  0.062339  0.273755  0.128833  ...  0.128877  0.114798  0.124000  0.104141
#
#        2018      2019      2020      2021      2022      2023
# 0  0.135999  0.143587  0.156940  0.150250  0.126723  0.193357
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.104896  0.104736  0.116552  0.120053  0.118359  0.111220
# 3  0.068902  0.080702  0.078555  0.079197  0.070461  0.070458
# 4  0.095039  0.085236  0.074624  0.066798  0.058413  0.055282
#
# [5 rows x 33 columns]

# %%
# Identify all year columns automatically (assuming they are from 1992 to 2023)
year_cols = [col for col in df_filtered.columns if col != 'Country']

# Convert columns to numeric just in case (but don't multiply!)
df_filtered[year_cols] = df_filtered[year_cols].apply(pd.to_numeric, errors='coerce') * 100

df_filtered.head()
# Out:
#    Country       1992       1993       1994       1995       1996       1997  \
# 0  Algeria   6.990372   7.086079   9.368375   9.354305  10.603947  11.751431
# 1    Libya        NaN        NaN        NaN        NaN        NaN  11.687259
# 2  Morocco  15.112962  15.810921  16.298257  16.003962  17.613954  17.780116
# 3  Tunisia   6.329051   6.191646   6.401790   6.258202   6.674142   6.709011
# 4   Angola        NaN        NaN        NaN        NaN   6.032920  13.875464
#
#         1998       1999       2000  ...       2014       2015       2016  \
# 0  12.717231  11.722227  12.004986  ...  13.437742  13.565596  15.203920
# 1  14.213519  11.525205  10.267775  ...  10.906788        NaN        NaN
# 2  17.034282  12.135690  10.904245  ...  11.078307  10.417622  10.444783
# 3   6.616900   6.178874   6.137680  ...   6.526302   7.795991   8.176006
# 4   6.233868  27.375517  12.883322  ...  12.887733  11.479843  12.399974
#
#         2017       2018       2019       2020       2021       2022       2023
# 0  14.640902  13.599871  14.358742  15.694046  15.024956  12.672319  19.335680
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2  10.592541  10.489648  10.473610  11.655206  12.005267  11.835927  11.122039
# 3   7.073337   6.890157   8.070219   7.855481   7.919698   7.046129   7.045826
# 4  10.414084   9.503913   8.523623   7.462364   6.679817   5.841265   5.528156
#
# [5 rows x 33 columns]

# %%
df_long = df_filtered.melt(
    id_vars='Country',
    var_name='Year',
    value_name='Defense_Spending'
)

# Convert Year to integer (if needed)
df_long['Year'] = df_long['Year'].astype(int)

# Optional: sort it nicely
df_long = df_long.sort_values(by=['Country', 'Year']).reset_index(drop=True)

# Reorder columns
df_long = df_long[['Year', 'Country', 'Defense_Spending']]

df_long.rename(columns={"Defense_Spending": "Defense_Share_GOV"}, inplace=True)

# Preview
print(df_long.head(10))
# Out:
#    Year      Country  Defense_Share_GOV
# 0  1992  Afghanistan                NaN
# 1  1993  Afghanistan                NaN
# 2  1994  Afghanistan                NaN
# 3  1995  Afghanistan                NaN
# 4  1996  Afghanistan                NaN
# 5  1997  Afghanistan                NaN
# 6  1998  Afghanistan                NaN
# 7  1999  Afghanistan                NaN
# 8  2000  Afghanistan                NaN
# 9  2001  Afghanistan                NaN

# %%
save_path = Path(r"C:\Users\snaja\OneDrive\defaidX\data\clean\sipri\milexp_share_gov_long_1992-2023.csv")

# Make sure the folder exists
save_path.parent.mkdir(parents=True, exist_ok=True)

# Save sorted dataframe
df_long.to_csv(save_path, index=False)

print(f"Cleaned and sorted file written to: {save_path}")
# Out:
# Cleaned and sorted file written to: C:\Users\snaja\OneDrive\defaidX\data\clean\sipri\milexp_share_gov_long_1992-2023.csv

# %%
# Assume the first column is 'Country' and all others are years (e.g., 1990–2023)
year_columns = df_filtered.columns[1:]  # Skip 'Country' column

# Count number of missing year values per country
df_filtered["Missing_Years"] = df_filtered[year_columns].isna().sum(axis=1)

# View countries sorted by how many years are missing
missing_summary = df_filtered[["Country", "Missing_Years"]].sort_values(by="Missing_Years", ascending=False)

missing_summary.head(10)
# Out:
#           Country  Missing_Years
# 76      Venezuela             32
# 125    Yugoslavia             32
# 165       Türkiye             32
# 141       Iceland             32
# 53           Cuba             32
# 89   Korea, North             32
# 52     Costa Rica             32
# 107  Turkmenistan             29
# 62         Panama             26
# 108    Uzbekistan             22

# %%
df_filtered.head()
# Out:
#    Country       1992       1993       1994       1995       1996       1997  \
# 0  Algeria   6.990372   7.086079   9.368375   9.354305  10.603947  11.751431
# 1    Libya        NaN        NaN        NaN        NaN        NaN  11.687259
# 2  Morocco  15.112962  15.810921  16.298257  16.003962  17.613954  17.780116
# 3  Tunisia   6.329051   6.191646   6.401790   6.258202   6.674142   6.709011
# 4   Angola        NaN        NaN        NaN        NaN   6.032920  13.875464
#
#         1998       1999       2000  ...       2015       2016       2017  \
# 0  12.717231  11.722227  12.004986  ...  13.565596  15.203920  14.640902
# 1  14.213519  11.525205  10.267775  ...        NaN        NaN        NaN
# 2  17.034282  12.135690  10.904245  ...  10.417622  10.444783  10.592541
# 3   6.616900   6.178874   6.137680  ...   7.795991   8.176006   7.073337
# 4   6.233868  27.375517  12.883322  ...  11.479843  12.399974  10.414084
#
#         2018       2019       2020       2021       2022       2023  \
# 0  13.599871  14.358742  15.694046  15.024956  12.672319  19.335680
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  10.489648  10.473610  11.655206  12.005267  11.835927  11.122039
# 3   6.890157   8.070219   7.855481   7.919698   7.046129   7.045826
# 4   9.503913   8.523623   7.462364   6.679817   5.841265   5.528156
#
#    Missing_Years
# 0              0
# 1             17
# 2              0
# 3              0
# 4              4
#
# [5 rows x 34 columns]

# %%
# Step 1: Count missing years per country (across all year columns)
missing_years_per_country = df_filtered.set_index('Country').isna().sum(axis=1)

# Step 2: Identify countries with more than 6 missing years
countries_to_drop = missing_years_per_country[missing_years_per_country > 10].index.tolist()
print(f"Number of countries to drop: {len(countries_to_drop)}")

# Step 3: Drop these countries from df_filtered
df_final = df_filtered[~df_filtered['Country'].isin(countries_to_drop)].reset_index(drop=True)

# Step 4: Check result
print(f"Remaining countries: {df_final['Country'].nunique()}")
df_final.head()
# Out:
# Number of countries to drop: 36
# Remaining countries: 132
#     Country       1992       1993       1994       1995       1996       1997  \
# 0   Algeria   6.990372   7.086079   9.368375   9.354305  10.603947  11.751431
# 1   Morocco  15.112962  15.810921  16.298257  16.003962  17.613954  17.780116
# 2   Tunisia   6.329051   6.191646   6.401790   6.258202   6.674142   6.709011
# 3    Angola        NaN        NaN        NaN        NaN   6.032920  13.875464
# 4  Botswana   9.897272  10.114546  10.226978   9.059052   7.726972   8.009500
#
#         1998       1999       2000  ...       2015       2016       2017  \
# 0  12.717231  11.722227  12.004986  ...  13.565596  15.203920  14.640902
# 1  17.034282  12.135690  10.904245  ...  10.417622  10.444783  10.592541
# 2   6.616900   6.178874   6.137680  ...   7.795991   8.176006   7.073337
# 3   6.233868  27.375517  12.883322  ...  11.479843  12.399974  10.414084
# 4   8.556251   7.521581   8.169209  ...   7.141479   9.964905   9.271060
#
#         2018       2019       2020       2021       2022       2023  \
# 0  13.599871  14.358742  15.694046  15.024956  12.672319  19.335680
# 1  10.489648  10.473610  11.655206  12.005267  11.835927  11.122039
# 2   6.890157   8.070219   7.855481   7.919698   7.046129   7.045826
# 3   9.503913   8.523623   7.462364   6.679817   5.841265   5.528156
# 4   8.149107   8.459592   8.662856   8.660597   8.094648   7.826500
#
#    Missing_Years
# 0              0
# 1              0
# 2              0
# 3              4
# 4              0
#
# [5 rows x 34 columns]

# %%
df_final = df_final.drop(columns=['Missing_Years'], errors='ignore')
df_final = df_final.reset_index(drop=True)

# %%
df_final.size
# Out:
# 4356

# %%
# Create a copy to preserve df_final
df_final_interpolated = df_final.copy()

# Identify year columns (excluding 'Country')
year_cols = df_final_interpolated.columns.difference(['Country'])

# Interpolate only missing values for each country across years
df_final_interpolated[year_cols] = df_final_interpolated[year_cols].apply(
    lambda row: row.interpolate(limit_direction='both'), axis=1
)

# Confirm if any NaNs remain (there shouldn't be, since we dropped >6-missing already)
missing_remaining = df_final_interpolated[year_cols].isna().sum().sum()
print(f"Total remaining missing values after interpolation: {missing_remaining}")
# Out:
# Total remaining missing values after interpolation: 0

# %%
df_final_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  132 non-null    object
#  1   1992     132 non-null    float64
#  2   1993     132 non-null    float64
#  3   1994     132 non-null    float64
#  4   1995     132 non-null    float64
#  5   1996     132 non-null    float64
#  6   1997     132 non-null    float64
#  7   1998     132 non-null    float64
#  8   1999     132 non-null    float64
#  9   2000     132 non-null    float64
#  10  2001     132 non-null    float64
#  11  2002     132 non-null    float64
#  12  2003     132 non-null    float64
#  13  2004     132 non-null    float64
#  14  2005     132 non-null    float64
#  15  2006     132 non-null    float64
#  16  2007     132 non-null    float64
#  17  2008     132 non-null    float64
#  18  2009     132 non-null    float64
#  19  2010     132 non-null    float64
#  20  2011     132 non-null    float64
#  21  2012     132 non-null    float64
#  22  2013     132 non-null    float64
#  23  2014     132 non-null    float64
#  24  2015     132 non-null    float64
#  25  2016     132 non-null    float64
#  26  2017     132 non-null    float64
#  27  2018     132 non-null    float64
#  28  2019     132 non-null    float64
#  29  2020     132 non-null    float64
#  30  2021     132 non-null    float64
#  31  2022     132 non-null    float64
#  32  2023     132 non-null    float64
# dtypes: float64(32), object(1)
# memory usage: 34.2+ KB

# %%
df_final_interpolated.tail()
# Out:
#           Country       1992       1993       1994       1995       1996  \
# 127        Kuwait  34.996221  20.268139  22.655707  24.881463  23.118151
# 128       Lebanon  22.403602  26.448498  14.990426  21.872385  13.166497
# 129          Oman  26.479800  25.097462  25.827441  25.013967  24.505543
# 130  Saudi Arabia  27.255134  32.834105  31.301293  28.448851  25.250231
# 131         Yemen  29.545412  27.419115  33.352214  26.321177  17.204348
#
#           1997       1998       1999       2000  ...       2014       2015  \
# 127  18.515295  16.913911  16.897305  19.558708  ...   8.097312   9.204345
# 128  10.766261  11.727747  13.584139  12.754870  ...  16.369634  16.824281
# 129  25.439732  22.738896  21.997439  22.696482  ...  21.393443  21.488502
# 130  30.722608  41.161212  37.369248  31.794149  ...  26.552604  32.652578
# 131  16.963917  17.745978  18.311590  15.511537  ...  14.279625  14.279625
#
#           2016       2017       2018       2019       2020       2021  \
# 127  10.910338  10.778772  10.019890  10.220920   9.873506  11.983610
# 128  18.017396  15.057808  15.639590  15.203105  15.479736  15.237042
# 129  23.676094  21.338106  21.574390  19.184120  18.030618  18.149025
# 130  27.747815  30.705065  25.937057  23.145420  22.505090  22.810006
# 131  14.279625  14.279625  14.279625  14.279625  14.279625  14.279625
#
#           2022       2023
# 127  11.225836   9.448221
# 128  10.719608  10.719608
# 129  16.984266  20.657363
# 130  22.672248  24.044520
# 131  14.279625  14.279625
#
# [5 rows x 33 columns]

# %%
unique_countries = df_final_interpolated['Country'].unique()
print(unique_countries)
# Out:
# ['Algeria' 'Morocco' 'Tunisia' 'Angola' 'Botswana' 'Burkina Faso'
#  'Burundi' 'Cameroon' 'Cabo Verde' 'Central African Republic' 'Chad'
#  'Congo, Dem. Rep.' 'Ivory Coast' 'Ethiopia' 'Ghana' 'Guinea'
#  'Guinea-Bissau' 'Kenya' 'Lesotho' 'Madagascar' 'Malawi' 'Mali'
#  'Mauritius' 'Mozambique' 'Namibia' 'Niger' 'Nigeria' 'Rwanda' 'Senegal'
#  'Seychelles' 'Sierra Leone' 'South Africa' 'Sudan' 'Eswatini' 'Tanzania'
#  'Togo' 'Uganda' 'Belize' 'Dominican Republic' 'El Salvador' 'Guatemala'
#  'Honduras' 'Jamaica' 'Mexico' 'Nicaragua' 'Trinidad and Tobago' 'Canada'
#  'United States' 'Argentina' 'Bolivia' 'Brazil' 'Chile' 'Colombia'
#  'Ecuador' 'Guyana' 'Paraguay' 'Peru' 'Uruguay' 'Australia' 'Fiji'
#  'New Zealand' 'Papua New Guinea' 'Bangladesh' 'India' 'Nepal' 'Pakistan'
#  'Sri Lanka' 'China' 'Japan' 'South Korea' 'Mongolia' 'Taiwan' 'Brunei'
#  'Cambodia' 'Indonesia' 'Malaysia' 'Philippines' 'Singapore' 'Thailand'
#  'Kazakhstan' 'Kyrgyz Republic' 'Tajikistan' 'Albania'
#  'Bosnia and Herzegovina' 'Bulgaria' 'Croatia' 'Czechia' 'Estonia'
#  'Hungary' 'Latvia' 'Lithuania' 'North Macedonia' 'Poland' 'Romania'
#  'Serbia' 'Slovakia' 'Slovenia' 'Azerbaijan' 'Belarus' 'Georgia' 'Moldova'
#  'Russia' 'Ukraine' 'Austria' 'Belgium' 'Cyprus' 'Denmark' 'Finland'
#  'France' 'Germany' 'Greece' 'Ireland' 'Italy' 'Luxembourg' 'Malta'
#  'Netherlands' 'Norway' 'Portugal' 'Spain' 'Sweden' 'Switzerland'
#  'United Kingdom' 'Bahrain' 'Egypt' 'Iran' 'Israel' 'Jordan' 'Kuwait'
#  'Lebanon' 'Oman' 'Saudi Arabia' 'Yemen']

# %%
missing_countries = df_final_interpolated[df_final_interpolated.isnull().any(axis=1)]["Country"].tolist()
print("Countries with missing years in df_final:")
print(missing_countries)
# Out:
# Countries with missing years in df_final:
# []

# %%
df_final_interpolated.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df_final_interpolated.head(10)
# Out:
#                     Country       1992       1993       1994       1995  \
# 0                   Algeria   6.990372   7.086079   9.368375   9.354305
# 1                   Morocco  15.112962  15.810921  16.298257  16.003962
# 2                   Tunisia   6.329051   6.191646   6.401790   6.258202
# 3                    Angola   6.032920   6.032920   6.032920   6.032920
# 4                  Botswana   9.897272  10.114546  10.226978   9.059052
# 5              Burkina Faso  11.246468   9.415326   7.961595   7.087145
# 6                   Burundi  11.853052  13.827599  20.105187  16.361996
# 7                  Cameroon   8.008987   8.008987   8.008987   8.008987
# 8                Cabo Verde   1.587660   1.587660   1.587660   2.445151
# 9  Central African Republic   7.033569   7.176235   5.606249   5.639134
#
# 9   10.923093   9.696503  12.719932
# 10  14.947975  14.595811  15.340982
# 11   3.428104   3.251999   6.963150
# 12   4.283742   3.917942   3.970675
# 13   3.565651   6.850634   7.537117
# 14   1.406524   1.249053   1.915030
# 15   9.958548  15.797695  13.817007
# 16   5.966820   6.766292   6.407471
# 17   4.485458   4.430270   4.114340
# 18   2.894918   2.762872   2.729008
# 19   4.952728   3.769468   3.454812
# 20   3.087818   3.497985   3.958136
# 21  12.568769  12.382093  14.183349
# 22   0.555857   0.475001   0.524061
# 23   6.212865   4.551344   5.626135
# 24   8.203174   7.986697   7.478685
# 25   5.594845   7.286515  10.225350
# 26   7.591828   4.517335   5.524900
# 27   4.790992   4.493809   4.554164
# 28   6.796022   5.722228   5.503640
# 29   6.363316   3.757173   4.430109
# 30   2.249526   2.332952   2.346326
# 31   2.477771   2.365006   2.210896
# 32   9.495772   9.495772   9.495772
# 33   5.779477   5.426902   4.724687
# 34   6.099351   5.926395   6.026805
# 35  10.949269  15.940409  12.718073
# 36  11.536222   9.655748   9.576290
# 37   4.272540   3.589076   3.584216
# 38   3.491452   3.608800   3.915256
# 39   3.821085   5.002662   4.655721
# 40   2.900984   3.235533   2.981787
# 41   5.207353   6.096066   5.859422
# 42   4.638579   4.126882   4.057579
# 43   2.471173   2.404924   2.369162
# 44   1.797251   1.889237   2.016990
# 45   2.829634   2.787004   2.821224
# 46   2.763640   2.886060   3.123651
# 47   8.038668   9.323326   9.055287
# 48   1.667721   1.841401   1.252315
# 49   3.854066   2.742530   4.202807
#
# [50 rows x 33 columns]

# %%
save_path = Path(r"C:\Users\snaja\OneDrive\defaidX\data\clean\sipri\milexp_share_gov_complete_wide_1992-2023.csv")

# Make sure the folder exists
save_path.parent.mkdir(parents=True, exist_ok=True)

# Save sorted dataframe
df_final_interpolated.to_csv(save_path, index=False)

print(f"Cleaned and sorted file written to: {save_path}")
# Out:
# Cleaned and sorted file written to: C:\Users\snaja\OneDrive\defaidX\data\clean\sipri\milexp_share_gov_complete_wide_1992-2023.csv

# %%
df_long_complete = df_final_interpolated.melt(
    id_vars='Country',
    var_name='Year',
    value_name='Defense_Spending'
)

# Convert Year to integer (if needed)
df_long_complete['Year'] = df_long_complete['Year'].astype(int)

# Optional: sort it nicely
df_long_complete = df_long_complete.sort_values(by=['Country', 'Year']).reset_index(drop=True)

# Reorder columns
df_long_complete = df_long_complete[['Year', 'Country', 'Defense_Spending']]

df_long_complete.rename(columns={"Defense_Spending": "Defense_Share_GOV"}, inplace=True)

# Preview
print(df_long_complete.head(10))
# Out:
#    Year  Country  Defense_Share_GOV
# 0  1992  Albania           4.424699
# 1  1993  Albania           4.424699
# 2  1994  Albania           4.424699
# 3  1995  Albania           4.424699
# 4  1996  Albania           4.424699
# 5  1997  Albania           4.424699
# 6  1998  Albania           3.582514
# 7  1999  Albania           3.578827
# 8  2000  Albania           3.843841
# 9  2001  Albania           4.147413

# %%
unique_countries = df_long_complete['Country'].unique()
print(unique_countries)
# Out:
# ['Albania' 'Algeria' 'Angola' 'Argentina' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahrain' 'Bangladesh' 'Belarus' 'Belgium' 'Belize'
#  'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'Brunei'
#  'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon'
#  'Canada' 'Central African Republic' 'Chad' 'Chile' 'China' 'Colombia'
#  'Congo, Dem. Rep.' 'Croatia' 'Cyprus' 'Czechia' 'Denmark'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Fiji' 'Finland' 'France' 'Georgia' 'Germany' 'Ghana' 'Greece'
#  'Guatemala' 'Guinea' 'Guinea-Bissau' 'Guyana' 'Honduras' 'Hungary'
#  'India' 'Indonesia' 'Iran' 'Ireland' 'Israel' 'Italy' 'Ivory Coast'
#  'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kuwait'
#  'Kyrgyz Republic' 'Latvia' 'Lebanon' 'Lesotho' 'Lithuania' 'Luxembourg'
#  'Madagascar' 'Malawi' 'Malaysia' 'Mali' 'Malta' 'Mauritius' 'Mexico'
#  'Moldova' 'Mongolia' 'Morocco' 'Mozambique' 'Namibia' 'Nepal'
#  'Netherlands' 'New Zealand' 'Nicaragua' 'Niger' 'Nigeria'
#  'North Macedonia' 'Norway' 'Oman' 'Pakistan' 'Papua New Guinea'
#  'Paraguay' 'Peru' 'Philippines' 'Poland' 'Portugal' 'Romania' 'Russia'
#  'Rwanda' 'Saudi Arabia' 'Senegal' 'Serbia' 'Seychelles' 'Sierra Leone'
#  'Singapore' 'Slovakia' 'Slovenia' 'South Africa' 'South Korea' 'Spain'
#  'Sri Lanka' 'Sudan' 'Sweden' 'Switzerland' 'Taiwan' 'Tajikistan'
#  'Tanzania' 'Thailand' 'Togo' 'Trinidad and Tobago' 'Tunisia' 'Uganda'
#  'Ukraine' 'United Kingdom' 'United States' 'Uruguay' 'Yemen']

# %%
df_long_complete.head(20)
# Out:
#     Year  Country  Defense_Share_GOV
# 0   1992  Albania           4.424699
# 1   1993  Albania           4.424699
# 2   1994  Albania           4.424699
# 3   1995  Albania           4.424699
# 4   1996  Albania           4.424699
# 5   1997  Albania           4.424699
# 6   1998  Albania           3.582514
# 7   1999  Albania           3.578827
# 8   2000  Albania           3.843841
# 9   2001  Albania           4.147413
# 10  2002  Albania           4.269753
# 11  2003  Albania           4.612929
# 12  2004  Albania           4.663211
# 13  2005  Albania           4.734375
# 14  2006  Albania           5.428989
# 15  2007  Albania           6.226081
# 16  2008  Albania           6.256198
# 17  2009  Albania           4.642727
# 18  2010  Albania           5.303742
# 19  2011  Albania           5.283864

# %%
save_path = Path(r"C:\\Users\\snaja\\OneDrive\\defaidX\\data\\clean\\sipri\\milexp_share_gov_complete_long_1992-2023.csv")

# Make sure the folder exists
save_path.parent.mkdir(parents=True, exist_ok=True)

# Save sorted dataframe
df_long_complete.to_csv(save_path, index=False)

print(f"Cleaned and sorted file written to: {save_path}")
# Out:
# Cleaned and sorted file written to: C:\Users\snaja\OneDrive\defaidX\data\clean\sipri\milexp_share_gov_complete_long_1992-2023.csv
